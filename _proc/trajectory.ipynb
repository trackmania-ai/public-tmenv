# %% [raw]
# ---
# description: Helpers to compute trajectory points from a ghost
# output-file: trajectory.html
# title: Trajectory
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(segment_project)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/trajectory.py#L24){target="_blank" style="float:right; font-size:smaller"}
#
# ### segment_project
#
# >      segment_project (p, a, b)

# %%
#| echo: false
#| output: asis
show_doc(segment_dists)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/trajectory.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### segment_dists
#
# >      segment_dists (p, a, b)

# %%
#| echo: false
#| output: asis
show_doc(Trajectory)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/trajectory.py#L33){target="_blank" style="float:right; font-size:smaller"}
#
# ### Trajectory
#
# >      Trajectory (ghost)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [raw]
# from tmenv.gbx import map_from_uid
#
# map = map_from_uid("uLTuyObJHgwQ3imynhvZzLHuHIm")
# ghost = map["ghosts"]["wr"]
# t = Trajectory(ghost)
