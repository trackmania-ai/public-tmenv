# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(TelemetryParser)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/socket.py#L47){target="_blank" style="float:right; font-size:smaller"}
#
# ### TelemetryParser
#
# >      TelemetryParser (conn)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(build_parser)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/socket.py#L41){target="_blank" style="float:right; font-size:smaller"}
#
# ### build_parser
#
# >      build_parser (name, format)

# %%
#| echo: false
#| output: asis
show_doc(ListValueParser)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/socket.py#L28){target="_blank" style="float:right; font-size:smaller"}
#
# ### ListValueParser
#
# >      ListValueParser (name, format)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(SimpleValueParser)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/socket.py#L18){target="_blank" style="float:right; font-size:smaller"}
#
# ### SimpleValueParser
#
# >      SimpleValueParser (name, format)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(Socket)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/socket.py#L62){target="_blank" style="float:right; font-size:smaller"}
#
# ### Socket
#
# >      Socket ()
#
# A class that represents a thread of control.
#
# This class can be safely subclassed in a limited fashion. There are two ways
# to specify the activity: by passing a callable object to the constructor, or
# by overriding the run() method in a subclass.
