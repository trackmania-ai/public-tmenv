# %% [raw]
# ---
# description: Retrieve and parse map and ghost gbx files
# output-file: gbx.html
# title: Gbx
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(parse_map)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L104){target="_blank" style="float:right; font-size:smaller"}
#
# ### parse_map
#
# >      parse_map (map_data)

# %%
#| echo: false
#| output: asis
show_doc(sanitize_map_name)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L100){target="_blank" style="float:right; font-size:smaller"}
#
# ### sanitize_map_name
#
# >      sanitize_map_name (map_name)

# %%
#| echo: false
#| output: asis
show_doc(parse_ghost)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L73){target="_blank" style="float:right; font-size:smaller"}
#
# ### parse_ghost
#
# >      parse_ghost (ghost_data)

# %%
#| echo: false
#| output: asis
show_doc(CorruptedGhostException)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L69){target="_blank" style="float:right; font-size:smaller"}
#
# ### CorruptedGhostException
#
#
#
# Common base class for all non-exit exceptions.

# %%
#| echo: false
#| output: asis
show_doc(parse_sample)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L56){target="_blank" style="float:right; font-size:smaller"}
#
# ### parse_sample
#
# >      parse_sample (sample_data)

# %%
#| echo: false
#| output: asis
show_doc(gbx_time_to_ms)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L52){target="_blank" style="float:right; font-size:smaller"}
#
# ### gbx_time_to_ms
#
# >      gbx_time_to_ms (time)

# %%
#| echo: false
#| output: asis
show_doc(gbx_data_from_file)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L47){target="_blank" style="float:right; font-size:smaller"}
#
# ### gbx_data_from_file
#
# >      gbx_data_from_file (path)

# %%
#| echo: false
#| output: asis
show_doc(gbx_data_from_url)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L42){target="_blank" style="float:right; font-size:smaller"}
#
# ### gbx_data_from_url
#
# >      gbx_data_from_url (url)

# %%
#| echo: false
#| output: asis
show_doc(gbx_bytes_to_json)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L32){target="_blank" style="float:right; font-size:smaller"}
#
# ### gbx_bytes_to_json
#
# >      gbx_bytes_to_json (gbx_bytes)

# %%
#| echo: false
#| output: asis
show_doc(ghost_from_file)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L159){target="_blank" style="float:right; font-size:smaller"}
#
# ### ghost_from_file
#
# >      ghost_from_file (path)

# %%
#| echo: false
#| output: asis
show_doc(ghost_from_url)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L155){target="_blank" style="float:right; font-size:smaller"}
#
# ### ghost_from_url
#
# >      ghost_from_url (url)

# %%
#| echo: false
#| output: asis
show_doc(ghost_wr_from_map_uid)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L143){target="_blank" style="float:right; font-size:smaller"}
#
# ### ghost_wr_from_map_uid
#
# >      ghost_wr_from_map_uid (uid)

# %%
#| echo: false
#| output: asis
show_doc(ghost_wr_url_from_map_uid)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L137){target="_blank" style="float:right; font-size:smaller"}
#
# ### ghost_wr_url_from_map_uid
#
# >      ghost_wr_url_from_map_uid (uid)

# %%
#| echo: false
#| output: asis
show_doc(map_from_file)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L133){target="_blank" style="float:right; font-size:smaller"}
#
# ### map_from_file
#
# >      map_from_file (path)

# %%
#| echo: false
#| output: asis
show_doc(map_url_from_uid)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L128){target="_blank" style="float:right; font-size:smaller"}
#
# ### map_url_from_uid
#
# >      map_url_from_uid (uid)

# %%
#| echo: false
#| output: asis
show_doc(map_from_uid)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L175){target="_blank" style="float:right; font-size:smaller"}
#
# ### map_from_uid
#
# >      map_from_uid (uid, fetch_wr=True)

# %%
#| echo: false
#| output: asis
show_doc(map_from_url)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L164){target="_blank" style="float:right; font-size:smaller"}
#
# ### map_from_url
#
# >      map_from_url (url, fetch_wr=True)

# %%
#| echo: false
#| output: asis
show_doc(campaigns_maps_uid)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L223){target="_blank" style="float:right; font-size:smaller"}
#
# ### campaigns_maps_uid
#
# >      campaigns_maps_uid (club_id, campaigns_id, slice)

# %%
#| echo: false
#| output: asis
show_doc(campaign)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L216){target="_blank" style="float:right; font-size:smaller"}
#
# ### campaign
#
# >      campaign (club_id, campaign_id)

# %%
#| echo: false
#| output: asis
show_doc(official_campaigns_maps_uid)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L206){target="_blank" style="float:right; font-size:smaller"}
#
# ### official_campaigns_maps_uid
#
# >      official_campaigns_maps_uid (campaigns_id, slice)

# %%
#| echo: false
#| output: asis
show_doc(campaign_maps_uid)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L202){target="_blank" style="float:right; font-size:smaller"}
#
# ### campaign_maps_uid
#
# >      campaign_maps_uid (campaign)

# %%
#| echo: false
#| output: asis
show_doc(official_campaigns)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L189){target="_blank" style="float:right; font-size:smaller"}
#
# ### official_campaigns
#
# >      official_campaigns ()

# %%
#| echo: false
#| output: asis
show_doc(official_campaign)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/gbx.py#L182){target="_blank" style="float:right; font-size:smaller"}
#
# ### official_campaign
#
# >      official_campaign (id)

# %% [raw]
# map_from_uid("gX4t_vf327VNALEK8yYDh66t60j")
