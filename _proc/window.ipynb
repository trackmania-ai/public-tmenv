# %% [raw]
# ---
# description: Api to capture and communicate with an X window
# output-file: window.html
# title: Window
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(MssCapture)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/window.py#L23){target="_blank" style="float:right; font-size:smaller"}
#
# ### MssCapture
#
# >      MssCapture (window_id)
#
# Multiple ScreenShots implementation for GNU/Linux.
# It uses intensively the Xlib and its Xrandr extension.

# %%
#| echo: false
#| output: asis
show_doc(Window)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/window.py#L52){target="_blank" style="float:right; font-size:smaller"}
#
# ### Window
#
# >      Window (title, sync=False)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(TmWindow)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/window.py#L164){target="_blank" style="float:right; font-size:smaller"}
#
# ### TmWindow
#
# >      TmWindow (title, sync=False)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [raw]
# w = TmWindow("template")
# w.capture_image()
