# %% [raw]
# ---
# description: Trackmania 2020 gym like environment for reinforcement learning
# output-file: tmenv.html
# title: Tmenv
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(MixedActionHandler)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/tmenv.py#L93){target="_blank" style="float:right; font-size:smaller"}
#
# ### MixedActionHandler
#
# >      MixedActionHandler ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(ContinuousActionHandler)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/tmenv.py#L73){target="_blank" style="float:right; font-size:smaller"}
#
# ### ContinuousActionHandler
#
# >      ContinuousActionHandler ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(DiscreteActionHandler)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/tmenv.py#L40){target="_blank" style="float:right; font-size:smaller"}
#
# ### DiscreteActionHandler
#
# >      DiscreteActionHandler (inter_steer=[])
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(ActionHandler)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/tmenv.py#L24){target="_blank" style="float:right; font-size:smaller"}
#
# ### ActionHandler
#
# >      ActionHandler ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(Tmenv)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/tmenv.py#L125){target="_blank" style="float:right; font-size:smaller"}
#
# ### Tmenv
#
# >      Tmenv (name, width, height, prefix_path, prefix_template_path,
# >             credential_path, timestep=0.1, wait_telemetry=True,
# >             telemetry_time=0.001, telemetry_timeout=0.5,
# >             action_handler=<__main__.DiscreteActionHandler object at
# >             0x7f57efaff460>, device='cpu', window_x=0, window_y=0)
#
# The main OpenAI Gym class.
#
# It encapsulates an environment with arbitrary behind-the-scenes dynamics.
# An environment can be partially or fully observed.
#
# The main API methods that users of this class need to know are:
#
# - :meth:`step` - Takes a step in the environment using an action returning the next observation, reward,
#   if the environment terminated and observation information.
# ...

# %%
#| echo: false
#| output: asis
show_doc(TelemetryTimeout)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/tmenv.py#L121){target="_blank" style="float:right; font-size:smaller"}
#
# ### TelemetryTimeout
#
#
#
# Common base class for all non-exit exceptions.

# %%
#| echo: false
#| output: asis
show_doc(MapNotLoadedException)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/tmenv.py#L117){target="_blank" style="float:right; font-size:smaller"}
#
# ### MapNotLoadedException
#
#
#
# Common base class for all non-exit exceptions.
