# %% [raw]
# ---
# description: Trackamania 2020 Game instance
# output-file: game.html
# title: Game
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Game)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/game.py#L34){target="_blank" style="float:right; font-size:smaller"}
#
# ### Game
#
# >      Game (name, width, height, prefix_path, prefix_template_path,
# >            credential_path, window_x=0, window_y=0)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(RespawnTimeoutException)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/game.py#L30){target="_blank" style="float:right; font-size:smaller"}
#
# ### RespawnTimeoutException
#
#
#
# Common base class for all non-exit exceptions.

# %%
#| echo: false
#| output: asis
show_doc(GiveUpTimeoutException)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/game.py#L26){target="_blank" style="float:right; font-size:smaller"}
#
# ### GiveUpTimeoutException
#
#
#
# Common base class for all non-exit exceptions.

# %%
#| echo: false
#| output: asis
show_doc(LoadMapTimeoutException)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/game.py#L22){target="_blank" style="float:right; font-size:smaller"}
#
# ### LoadMapTimeoutException
#
#
#
# Common base class for all non-exit exceptions.

# %% [raw]
# import logging
#
# logger = logging.getLogger()
# logger.setLevel(logging.DEBUG)
#
# import getpass
#
# from tmenv.gbx import map_from_uid
#
# tmwine = Path(f"/home/{getpass.getuser()}/Development/tmwine")
# name = "tmai4"
# game = Game(
#     name=name,
#     width=960,
#     height=540,
#     prefix_path=tmwine / name,
#     prefix_template_path=tmwine / "template",
#     credential_path=tmwine / "credentials" / f"{name}.user.dat",
# )
# game.load_map(map_from_uid("gX4t_vf327VNALEK8yYDh66t60j")["url"])
# game.toggle_interface()
# game.input_lag()
# sleep(5)
# game.input_lag()
