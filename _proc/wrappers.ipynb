# %% [raw]
# ---
# description: Env wrappers for tmenv
# output-file: wrappers.html
# title: Wrappers
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(StateWrapper)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/wrappers.py#L25){target="_blank" style="float:right; font-size:smaller"}
#
# ### StateWrapper
#
# >      StateWrapper (env, state_space)
#
# Wraps an environment to allow a modular transformation of the :meth:`step` and :meth:`reset` methods.
#
# This class is the base class for all wrappers. The subclass could override
# some methods to change the behavior of the original environment without touching the
# original code.
#
# Note:
#     Don't forget to call ``super().__init__(env)`` if the subclass overrides :meth:`__init__`.

# %%
#| echo: false
#| output: asis
show_doc(VisualState)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/wrappers.py#L53){target="_blank" style="float:right; font-size:smaller"}
#
# ### VisualState
#
# >      VisualState (env, shape, div=255.0)
#
# Wraps an environment to allow a modular transformation of the :meth:`step` and :meth:`reset` methods.
#
# This class is the base class for all wrappers. The subclass could override
# some methods to change the behavior of the original environment without touching the
# original code.
#
# Note:
#     Don't forget to call ``super().__init__(env)`` if the subclass overrides :meth:`__init__`.

# %%
#| echo: false
#| output: asis
show_doc(vec2np)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/wrappers.py#L69){target="_blank" style="float:right; font-size:smaller"}
#
# ### vec2np
#
# >      vec2np (vec)

# %%
#| echo: false
#| output: asis
show_doc(RotationEnvWrapper)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/wrappers.py#L86){target="_blank" style="float:right; font-size:smaller"}
#
# ### RotationEnvWrapper
#
# >      RotationEnvWrapper (env)
#
# Wraps an environment to allow a modular transformation of the :meth:`step` and :meth:`reset` methods.
#
# This class is the base class for all wrappers. The subclass could override
# some methods to change the behavior of the original environment without touching the
# original code.
#
# Note:
#     Don't forget to call ``super().__init__(env)`` if the subclass overrides :meth:`__init__`.

# %%
#| echo: false
#| output: asis
show_doc(angle_diff)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/wrappers.py#L82){target="_blank" style="float:right; font-size:smaller"}
#
# ### angle_diff
#
# >      angle_diff (a, b)

# %%
#| echo: false
#| output: asis
show_doc(vec2rotation)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/wrappers.py#L76){target="_blank" style="float:right; font-size:smaller"}
#
# ### vec2rotation
#
# >      vec2rotation (forward, left, up)

# %%
#| echo: false
#| output: asis
show_doc(TrajectoryEnvWrapper)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/wrappers.py#L148){target="_blank" style="float:right; font-size:smaller"}
#
# ### TrajectoryEnvWrapper
#
# >      TrajectoryEnvWrapper (env, max_distance, ghost_types=['author', 'wr'],
# >                            jump_z_coef=0.5, minimum_speed=5,
# >                            maximum_travel=300)
#
# Wraps an environment to allow a modular transformation of the :meth:`step` and :meth:`reset` methods.
#
# This class is the base class for all wrappers. The subclass could override
# some methods to change the behavior of the original environment without touching the
# original code.
#
# Note:
#     Don't forget to call ``super().__init__(env)`` if the subclass overrides :meth:`__init__`.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | env |  |  |  |
# | max_distance |  |  |  |
# | ghost_types | list | ['author', 'wr'] |  |
# ...

# %%
#| echo: false
#| output: asis
show_doc(TelemetryState)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/wrappers.py#L261){target="_blank" style="float:right; font-size:smaller"}
#
# ### TelemetryState
#
# >      TelemetryState (env, telemetry_lag_divisor=20, env_lag_divisor=0.1)
#
# Wraps an environment to allow a modular transformation of the :meth:`step` and :meth:`reset` methods.
#
# This class is the base class for all wrappers. The subclass could override
# some methods to change the behavior of the original environment without touching the
# original code.
#
# Note:
#     Don't forget to call ``super().__init__(env)`` if the subclass overrides :meth:`__init__`.

# %%
#| echo: false
#| output: asis
show_doc(WheelState)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/wrappers.py#L341){target="_blank" style="float:right; font-size:smaller"}
#
# ### WheelState
#
# >      WheelState (env)
#
# Wraps an environment to allow a modular transformation of the :meth:`step` and :meth:`reset` methods.
#
# This class is the base class for all wrappers. The subclass could override
# some methods to change the behavior of the original environment without touching the
# original code.
#
# Note:
#     Don't forget to call ``super().__init__(env)`` if the subclass overrides :meth:`__init__`.

# %%
#| echo: false
#| output: asis
show_doc(AlignedState)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/wrappers.py#L400){target="_blank" style="float:right; font-size:smaller"}
#
# ### AlignedState
#
# >      AlignedState (env)
#
# Wraps an environment to allow a modular transformation of the :meth:`step` and :meth:`reset` methods.
#
# This class is the base class for all wrappers. The subclass could override
# some methods to change the behavior of the original environment without touching the
# original code.
#
# Note:
#     Don't forget to call ``super().__init__(env)`` if the subclass overrides :meth:`__init__`.

# %%
#| echo: false
#| output: asis
show_doc(TrajectoryState)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/wrappers.py#L380){target="_blank" style="float:right; font-size:smaller"}
#
# ### TrajectoryState
#
# >      TrajectoryState (env, nb_positions, spacing)
#
# Wraps an environment to allow a modular transformation of the :meth:`step` and :meth:`reset` methods.
#
# This class is the base class for all wrappers. The subclass could override
# some methods to change the behavior of the original environment without touching the
# original code.
#
# Note:
#     Don't forget to call ``super().__init__(env)`` if the subclass overrides :meth:`__init__`.

# %%
#| echo: false
#| output: asis
show_doc(MapState)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/wrappers.py#L432){target="_blank" style="float:right; font-size:smaller"}
#
# ### MapState
#
# >      MapState (env, d_model=16)
#
# Wraps an environment to allow a modular transformation of the :meth:`step` and :meth:`reset` methods.
#
# This class is the base class for all wrappers. The subclass could override
# some methods to change the behavior of the original environment without touching the
# original code.
#
# Note:
#     Don't forget to call ``super().__init__(env)`` if the subclass overrides :meth:`__init__`.

# %%
#| echo: false
#| output: asis
show_doc(PositionalEncoder)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/wrappers.py#L417){target="_blank" style="float:right; font-size:smaller"}
#
# ### PositionalEncoder
#
# >      PositionalEncoder (d_model, min_freq=0.0001, device='cpu')
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(TrajectoryDoneWrapper)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/wrappers.py#L446){target="_blank" style="float:right; font-size:smaller"}
#
# ### TrajectoryDoneWrapper
#
# >      TrajectoryDoneWrapper (env, max_mistake_duration,
# >                             respawn_sequence=['launched', 'standing',
# >                             'launched', 'standing'],
# >                             give_up_before_first_cp=True)
#
# Wraps an environment to allow a modular transformation of the :meth:`step` and :meth:`reset` methods.
#
# This class is the base class for all wrappers. The subclass could override
# some methods to change the behavior of the original environment without touching the
# original code.
#
# Note:
#     Don't forget to call ``super().__init__(env)`` if the subclass overrides :meth:`__init__`.

# %%
#| echo: false
#| output: asis
show_doc(TrajectoryTravelRewardWrapper)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/wrappers.py#L516){target="_blank" style="float:right; font-size:smaller"}
#
# ### TrajectoryTravelRewardWrapper
#
# >      TrajectoryTravelRewardWrapper (env, mistake_reward, discount_factor,
# >                                     penalty_threshold=0.0)
#
# Wraps an environment to allow a modular transformation of the :meth:`step` and :meth:`reset` methods.
#
# This class is the base class for all wrappers. The subclass could override
# some methods to change the behavior of the original environment without touching the
# original code.
#
# Note:
#     Don't forget to call ``super().__init__(env)`` if the subclass overrides :meth:`__init__`.

# %%
#| echo: false
#| output: asis
show_doc(EpisodeInfoWrapper)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/wrappers.py#L575){target="_blank" style="float:right; font-size:smaller"}
#
# ### EpisodeInfoWrapper
#
# >      EpisodeInfoWrapper (env:gym.core.Env)
#
# Wraps an environment to allow a modular transformation of the :meth:`step` and :meth:`reset` methods.
#
# This class is the base class for all wrappers. The subclass could override
# some methods to change the behavior of the original environment without touching the
# original code.
#
# Note:
#     Don't forget to call ``super().__init__(env)`` if the subclass overrides :meth:`__init__`.
