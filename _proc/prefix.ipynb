# %% [raw]
# ---
# description: Wine prefix manager for Trackmania 2020
# output-file: prefix.html
# title: Prefix
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Prefix)
# Out:
# ---
#
# [source](https://github.com/trackmania-ai/tmenv/tree/master/blob/master/tmenv/prefix.py#L16){target="_blank" style="float:right; font-size:smaller"}
#
# ### Prefix
#
# >      Prefix (name, width, height, prefix_path, prefix_template_path,
# >              credential_path, socket_port)
#
# Initialize self.  See help(type(self)) for accurate signature.
